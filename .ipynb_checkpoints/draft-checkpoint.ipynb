# %% [markdown]
# ## introduction

# %% [markdown]
# ## table of contents

# %% [markdown]
# ## import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## import data

# %%
df_all = pd.read_csv('data/Kickstarter.csv')

# %%
df_all.head()
# Out:
#    backers_count                                              blurb  \
# 0              4  Soaps made with love, care, creativity and you...
# 1             35  Pens made from Whiskey barrels, Jack Daniel's ...
# 2            310  Finally we have a building but we need your he...
# 3              1  Everything home made in one store. From jewelr...
# 4             36  Growing My Natural, Eco-Friendly, and Fun Bath...
#
#                                             category  \
# 0  {"id":345,"name":"DIY","slug":"crafts/diy","po...
# 1  {"id":356,"name":"Woodworking","slug":"crafts/...
# 2  {"id":256,"name":"Spaces","slug":"dance/spaces...
# 3  {"id":345,"name":"DIY","slug":"crafts/diy","po...
# 4  {"id":343,"name":"Candles","slug":"crafts/cand...
#
#    converted_pledged_amount country country_displayable_name  created_at  \
# 0                        41      US        the United States  1512430228
# 1                      2205      US        the United States  1528377129
# 2                      8861      US        the United States  1443014021
# 3                       100      US        the United States  1412436646
# 4                      1026      US        the United States  1599615992
#
#                                              creator currency currency_symbol  \
# 0  {"id":513003716,"name":"Lisa Alaniz","slug":"t...      USD               $
# 1  {"id":2022066517,"name":"Brad McKee","is_regis...      USD               $
# 2  {"id":988974145,"name":"Sherrod & Rashon","is_...      USD               $
# 3  {"id":1794353539,"name":"Jessica Carl","is_reg...      USD               $
# 4  {"id":1149297269,"name":"Victoria Adella","slu...      USD               $
#
#    ...                  slug  \
# 0  ...        soaps-in-texas
# 1  ...          whiskey-pens
# 2  ...      the-posh-factory
# 3  ...             home-made
# 4  ...  goofy-goat-soaps-llc
#
#                                           source_url  spotlight  staff_pick  \
# 0  https://www.kickstarter.com/discover/categorie...      False       False
# 1  https://www.kickstarter.com/discover/categorie...       True       False
# 2  https://www.kickstarter.com/discover/categorie...       True       False
# 3  https://www.kickstarter.com/discover/categorie...      False       False
# 4  https://www.kickstarter.com/discover/categorie...       True        True
#
#         state  state_changed_at  static_usd_rate  \
# 0      failed        1515102534              1.0
# 1  successful        1531325825              1.0
# 2  successful        1447620376              1.0
# 3      failed        1415406440              1.0
# 4  successful        1602385860              1.0
#
#                                                 urls usd_pledged  \
# 0  {"web":{"project":"https://www.kickstarter.com...        41.0
# 1  {"web":{"project":"https://www.kickstarter.com...      2205.0
# 2  {"web":{"project":"https://www.kickstarter.com...      8861.0
# 3  {"web":{"project":"https://www.kickstarter.com...       100.0
# 4  {"web":{"project":"https://www.kickstarter.com...      1026.0
#
#         usd_type
# 0  international
# 1  international
# 2  international
# 3  international
# 4  international
#
# [5 rows x 38 columns]

# %%
df_all.columns
# Out:
# Index(['backers_count', 'blurb', 'category', 'converted_pledged_amount',
#        'country', 'country_displayable_name', 'created_at', 'creator',
#        'currency', 'currency_symbol', 'currency_trailing_code',
#        'current_currency', 'deadline', 'disable_communication', 'friends',
#        'fx_rate', 'goal', 'id', 'is_backing', 'is_starrable', 'is_starred',
#        'launched_at', 'location', 'name', 'permissions', 'photo', 'pledged',
#        'profile', 'slug', 'source_url', 'spotlight', 'staff_pick', 'state',
#        'state_changed_at', 'static_usd_rate', 'urls', 'usd_pledged',
#        'usd_type'],
#       dtype='object')

# %%
df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3686 entries, 0 to 3685
# Data columns (total 38 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   backers_count             3686 non-null   int64
#  1   blurb                     3686 non-null   object
#  2   category                  3686 non-null   object
#  3   converted_pledged_amount  3686 non-null   int64
#  4   country                   3686 non-null   object
#  5   country_displayable_name  3686 non-null   object
#  6   created_at                3686 non-null   int64
#  7   creator                   3686 non-null   object
#  8   currency                  3686 non-null   object
#  9   currency_symbol           3686 non-null   object
#  10  currency_trailing_code    3686 non-null   bool
#  11  current_currency          3686 non-null   object
#  12  deadline                  3686 non-null   int64
#  13  disable_communication     3686 non-null   bool
#  14  friends                   4 non-null      object
#  15  fx_rate                   3686 non-null   float64
#  16  goal                      3686 non-null   float64
#  17  id                        3686 non-null   int64
#  18  is_backing                4 non-null      object
#  19  is_starrable              3686 non-null   bool
#  20  is_starred                4 non-null      object
#  21  launched_at               3686 non-null   int64
#  22  location                  3680 non-null   object
#  23  name                      3686 non-null   object
#  24  permissions               4 non-null      object
#  25  photo                     3686 non-null   object
#  26  pledged                   3686 non-null   float64
#  27  profile                   3686 non-null   object
#  28  slug                      3686 non-null   object
#  29  source_url                3686 non-null   object
#  30  spotlight                 3686 non-null   bool
#  31  staff_pick                3686 non-null   bool
#  32  state                     3686 non-null   object
#  33  state_changed_at          3686 non-null   int64
#  34  static_usd_rate           3686 non-null   float64
#  35  urls                      3686 non-null   object
#  36  usd_pledged               3686 non-null   float64
#  37  usd_type                  3686 non-null   object
# dtypes: bool(5), float64(5), int64(7), object(21)
# memory usage: 968.4+ KB

# %%
df_all.shape
# Out:
# (3686, 38)

# %% [markdown]
# ## data preprocessing

# %% [markdown]
# ### for non useful columns

# %%
# drop columns containing mostly null values
df = df_all.drop(['friends', 'is_backing', 'is_starred', 'permissions'], axis=1, inplace=False)

# %% [markdown]
# Other columns are not useful for the purposes of this project, and can also be dropped for these reasons:
#
# - converted_pledged_amount - most currencies are converted into USD in this column, but not all. Instead, the 'usd_pledged' column will be used as these all use the same currency (the dollar).
# - creator - most projects are by different people, and so this cannot be usefully used to group or categorise projects, and is not useful in a machine learning context.
# - currency - all currency values will be used as/converted to dollars, so that they can be evaluated together. It is not necessary to keep the original record because of this, and because it will be highly correlated with country (which will be kept).
# - currency_symbol - as above.
# - currency_trailing_code - as above.
# - current_currency - as above.
# - fx_rate - this is used to create 'converted_pledged_amount' from 'pledged', but does not always convert to dollars so can be dropped in favour of 'static_usd_rate' which always converts to dollars.
# - photo - image processing/computer vision will not be used in this project.
# - pledged - data in this column is stored in native currencies, so this will be dropped in favour of 'usd_pledged' which is all in the same currency (dollars).
# - profile - this column contains a combination of information from other columns (e.g. id, state, dates, url).
# - slug - this is simply the 'name' column with hyphens instead of spaces.
# - source_url - the sites that the rows were each scraped from is not useful for building a model, as each is unique to an id.
# - spotlight - projects can only be spotlighted after they are already successful, so this will be entirely correlated with successful projects.
# - state_changed_at - this is the same as deadline for most projects. The only exceptions are for projects which were cancelled before their deadline, but they will not be included in this analysis.
# - urls - as with source_url.
# - usd_type - it is unclear what this column means, but it is unlikely to be necessary since all currency values will be converted to dollars, and other currency information has been dropped.

# %%
# drop columns that are not useful
df.drop(['converted_pledged_amount', 'creator', 'currency', 'currency_symbol', 
         'currency_trailing_code', 'current_currency', 'fx_rate', 'photo', 'pledged', 
         'profile', 'slug', 'source_url', 'spotlight', 'state_changed_at', 'urls', 
         'usd_type'], axis=1, inplace=True)

# %% [markdown]
# ### for datetime columns

# %%
# Converting dates from unix to datetime
date_cols = ['created_at', 'deadline', 'launched_at']
for col in date_cols:
    df[[col]] = pd.to_datetime(df[col], origin='unix', unit='s')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3686 entries, 0 to 3685
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   backers_count             3686 non-null   int64
#  1   blurb                     3686 non-null   object
#  2   category                  3686 non-null   object
#  3   country                   3686 non-null   object
#  4   country_displayable_name  3686 non-null   object
#  5   created_at                3686 non-null   datetime64[ns]
#  6   deadline                  3686 non-null   datetime64[ns]
#  7   disable_communication     3686 non-null   bool
#  8   goal                      3686 non-null   float64
#  9   id                        3686 non-null   int64
#  10  is_starrable              3686 non-null   bool
#  11  launched_at               3686 non-null   datetime64[ns]
#  12  location                  3680 non-null   object
#  13  name                      3686 non-null   object
#  14  staff_pick                3686 non-null   bool
#  15  state                     3686 non-null   object
#  16  static_usd_rate           3686 non-null   float64
#  17  usd_pledged               3686 non-null   float64
# dtypes: bool(3), datetime64[ns](3), float64(3), int64(2), object(7)
# memory usage: 442.9+ KB

# %% [markdown]
# ### for duplicate rows

# %%
#see possible duplicate rows by 'id'
df.duplicated(subset='id').sum()
# Out:
# 9

# %%
#see possible duplicate rows by 'blurb'
df.duplicated(subset='blurb').sum()
# Out:
# 10

# %%
ids = df["id"]
df[ids.isin(ids[ids.duplicated()])][index]
# Out:
#       backers_count                                              blurb  \
# 203              15  The "Mandalali" is a creative Mandala drawing ...
# 363              15  The "Mandalali" is a creative Mandala drawing ...
# 402              48  Supernatural Post-Apocalyptic Comic set in the...
# 586             142  An EMS Sportswear is helping you achieve maxim...
# 604              31  The Recovery Box is about the size of a slice ...
# 675              31  The Recovery Box is about the size of a slice ...
# 937            3925  Light your Charcoal Grill in 60 Seconds! Sear ...
# 988             142  An EMS Sportswear is helping you achieve maxim...
# 1111             13  B.E.A.R. :   Bewilder Eavesdropping Audio Reco...
# 1152           3925  Light your Charcoal Grill in 60 Seconds! Sear ...
# 1190             13  B.E.A.R. :   Bewilder Eavesdropping Audio Reco...
# 1612             54  Limited Edition Illustrative Multicultural Sto...
# 1777             54  Limited Edition Illustrative Multicultural Sto...
# 2475             13  A set of 12 hard enamel pins and stickers insp...
# 2535            354  The Black Painters Academy is a place for joy ...
# 2725             13  A set of 12 hard enamel pins and stickers insp...
# 2748            354  The Black Painters Academy is a place for joy ...
# 3251             48  Supernatural Post-Apocalyptic Comic set in the...
#
#                                                category country  \
# 203   {"id":345,"name":"DIY","slug":"crafts/diy","po...      ES
# 363   {"id":345,"name":"DIY","slug":"crafts/diy","po...      ES
# 402   {"id":252,"name":"Graphic Novels","slug":"comi...      US
# 586   {"id":341,"name":"Wearables","slug":"technolog...      HK
# 604   {"id":52,"name":"Hardware","slug":"technology/...      AU
# 675   {"id":52,"name":"Hardware","slug":"technology/...      AU
# 937   {"id":337,"name":"Gadgets","slug":"technology/...      US
# 988   {"id":341,"name":"Wearables","slug":"technolog...      HK
# 1111  {"id":337,"name":"Gadgets","slug":"technology/...      US
# 1152  {"id":337,"name":"Gadgets","slug":"technology/...      US
# 1190  {"id":337,"name":"Gadgets","slug":"technology/...      US
# 1612  {"id":46,"name":"Children's Books","slug":"pub...      US
# 1777  {"id":46,"name":"Children's Books","slug":"pub...      US
# 2475  {"id":21,"name":"Digital Art","slug":"art/digi...      US
# 2535  {"id":23,"name":"Painting","slug":"art/paintin...      US
# 2725  {"id":21,"name":"Digital Art","slug":"art/digi...      US
# 2748  {"id":23,"name":"Painting","slug":"art/paintin...      US
# 3251  {"id":252,"name":"Graphic Novels","slug":"comi...      US
#
#      country_displayable_name          created_at            deadline  \
# 203                     Spain 2021-01-10 08:44:34 2021-03-18 14:27:57
# 363                     Spain 2021-01-10 08:44:34 2021-03-18 14:27:57
# 402         the United States 2019-10-18 15:38:16 2019-12-04 02:56:54
# 586                 Hong Kong 2019-07-29 11:51:39 2019-10-04 13:30:03
# 604                 Australia 2019-12-07 22:55:31 2020-04-29 22:01:09
# 675                 Australia 2019-12-07 22:55:31 2020-04-29 22:01:09
# 937         the United States 2019-02-11 15:56:10 2019-07-02 03:54:32
# 988                 Hong Kong 2019-07-29 11:51:39 2019-10-04 13:30:03
# 1111        the United States 2020-07-05 20:21:40 2020-08-19 19:56:52
# 1152        the United States 2019-02-11 15:56:10 2019-07-02 03:54:32
# 1190        the United States 2020-07-05 20:21:40 2020-08-19 19:56:52
# 1612        the United States 2020-12-06 17:01:36 2021-02-18 15:55:15
# 1777        the United States 2020-12-06 17:01:36 2021-02-18 15:55:15
# 2475        the United States 2021-02-28 09:56:18 2021-03-29 04:59:00
# 2535        the United States 2020-10-22 18:03:45 2020-12-15 19:55:39
# 2725        the United States 2021-02-28 09:56:18 2021-03-29 04:59:00
# 2748        the United States 2020-10-22 18:03:45 2020-12-15 19:55:39
# 3251        the United States 2019-10-18 15:38:16 2019-12-04 02:56:54
#
#       disable_communication      goal          id  is_starrable  \
# 203                   False   14100.0   528274403         False
# 363                   False   14100.0   528274403         False
# 402                   False     500.0  1880551383         False
# 586                   False  150000.0  1282938902         False
# 604                   False   10800.0   905929551         False
# 675                   False   10800.0   905929551         False
# 937                   False   60000.0   372360890         False
# 988                   False  150000.0  1282938902         False
# 1111                  False     300.0   881319076         False
# 1152                  False   60000.0   372360890         False
# 1190                  False     300.0   881319076         False
# 1612                  False     500.0   825031170         False
# 1777                  False     500.0   825031170         False
# 2475                  False     300.0  1829720595          True
# 2535                  False   18000.0   522881743         False
# 2725                  False     300.0  1829720595          True
# 2748                  False   18000.0   522881743         False
# 3251                  False     500.0  1880551383         False
#
#              launched_at                                           location  \
# 203  2021-02-11 15:27:57  {"id":753692,"name":"Barcelona","slug":"barcel...
# 363  2021-02-11 15:27:57  {"id":753692,"name":"Barcelona","slug":"barcel...
# 402  2019-11-04 02:56:54  {"id":2490383,"name":"Seattle","slug":"seattle...
# 586  2019-08-15 13:30:03  {"id":2390774,"name":"Delaware","slug":"delawa...
# 604  2020-02-29 23:01:09  {"id":1104584,"name":"Newcastle","slug":"newca...
# 675  2020-02-29 23:01:09  {"id":1104584,"name":"Newcastle","slug":"newca...
# 937  2019-05-23 03:54:32  {"id":2508533,"name":"Tulsa","slug":"tulsa-ok"...
# 988  2019-08-15 13:30:03  {"id":2390774,"name":"Delaware","slug":"delawa...
# 1111 2020-07-20 19:56:52  {"id":2433074,"name":"Kirkland","slug":"kirkla...
# 1152 2019-05-23 03:54:32  {"id":2508533,"name":"Tulsa","slug":"tulsa-ok"...
# 1190 2020-07-20 19:56:52  {"id":2433074,"name":"Kirkland","slug":"kirkla...
# 1612 2021-01-12 15:55:15  {"id":2487956,"name":"San Francisco","slug":"s...
# 1777 2021-01-12 15:55:15  {"id":2487956,"name":"San Francisco","slug":"s...
# 2475 2021-03-08 06:25:05  {"id":2424766,"name":"Houston","slug":"houston...
# 2535 2020-11-10 19:55:39  {"id":12589342,"name":"Manhattan","slug":"manh...
# 2725 2021-03-08 06:25:05  {"id":2424766,"name":"Houston","slug":"houston...
# 2748 2020-11-10 19:55:39  {"id":12589342,"name":"Manhattan","slug":"manh...
# 3251 2019-11-04 02:56:54  {"id":2490383,"name":"Seattle","slug":"seattle...
#
#                                                    name  staff_pick  \
# 203                       Self Unlimited Create Mandala       False
# 363                       Self Unlimited Create Mandala       False
# 402      The Book of Jessica Issue 4 AND Graphic Novel.       False
# 586   Wisenfit: New Generation Phone-Powered Electri...       False
# 604                                        Recovery Box       False
# 675                                        Recovery Box       False
# 937          The GRILLGUN..."The Ultimate Grill Torch!"       False
# 988   Wisenfit: New Generation Phone-Powered Electri...       False
# 1111  B.E.A.R. Privacy: Touch-less Protection for Sm...       False
# 1152         The GRILLGUN..."The Ultimate Grill Torch!"       False
# 1190  B.E.A.R. Privacy: Touch-less Protection for Sm...       False
# 1612  Make 100 : UMA – A Children’s Book About Hindu...        True
# 1777  Make 100 : UMA – A Children’s Book About Hindu...        True
# 2475                Lunar New Year Zodiacs: Enamel Pins       False
# 2535  Help us make a permanent home for The Black Pa...        True
# 2725                Lunar New Year Zodiacs: Enamel Pins       False
# 2748  Help us make a permanent home for The Black Pa...        True
# 3251     The Book of Jessica Issue 4 AND Graphic Novel.       False
#
#            state  static_usd_rate    usd_pledged
# 203         live         1.212886     918.154475
# 363         live         1.212886     918.154475
# 402   successful         1.000000     983.000000
# 586   successful         0.127454   43191.709795
# 604   successful         0.652425    7176.884876
# 675   successful         0.652425    7176.884876
# 937   successful         1.000000  405913.000000
# 988   successful         0.127454   43191.709795
# 1111  successful         1.000000     516.000000
# 1152  successful         1.000000  405913.000000
# 1190  successful         1.000000     516.000000
# 1612  successful         1.000000    1471.000000
# 1777  successful         1.000000    1471.000000
# 2475        live         1.000000     445.000000
# 2535  successful         1.000000   22240.000000
# 2725        live         1.000000     445.000000
# 2748  successful         1.000000   22240.000000
# 3251  successful         1.000000     983.000000

# %%
blurbs = df["blurb"]
df[blurbs.isin(blurbs[blurbs.duplicated()])]
# Out:
#       backers_count                                              blurb  \
# 203              15  The "Mandalali" is a creative Mandala drawing ...
# 363              15  The "Mandalali" is a creative Mandala drawing ...
# 402              48  Supernatural Post-Apocalyptic Comic set in the...
# 586             142  An EMS Sportswear is helping you achieve maxim...
# 604              31  The Recovery Box is about the size of a slice ...
# 675              31  The Recovery Box is about the size of a slice ...
# 937            3925  Light your Charcoal Grill in 60 Seconds! Sear ...
# 988             142  An EMS Sportswear is helping you achieve maxim...
# 1111             13  B.E.A.R. :   Bewilder Eavesdropping Audio Reco...
# 1152           3925  Light your Charcoal Grill in 60 Seconds! Sear ...
# 1190             13  B.E.A.R. :   Bewilder Eavesdropping Audio Reco...
# 1612             54  Limited Edition Illustrative Multicultural Sto...
# 1777             54  Limited Edition Illustrative Multicultural Sto...
# 2475             13  A set of 12 hard enamel pins and stickers insp...
# 2535            354  The Black Painters Academy is a place for joy ...
# 2561             28  A group of American artists exchanging creativ...
# 2725             13  A set of 12 hard enamel pins and stickers insp...
# 2748            354  The Black Painters Academy is a place for joy ...
# 2994             52  A group of American artists exchanging creativ...
# 3251             48  Supernatural Post-Apocalyptic Comic set in the...
#
#                                                category country  \
# 203   {"id":345,"name":"DIY","slug":"crafts/diy","po...      ES
# 363   {"id":345,"name":"DIY","slug":"crafts/diy","po...      ES
# 402   {"id":252,"name":"Graphic Novels","slug":"comi...      US
# 586   {"id":341,"name":"Wearables","slug":"technolog...      HK
# 604   {"id":52,"name":"Hardware","slug":"technology/...      AU
# 675   {"id":52,"name":"Hardware","slug":"technology/...      AU
# 937   {"id":337,"name":"Gadgets","slug":"technology/...      US
# 988   {"id":341,"name":"Wearables","slug":"technolog...      HK
# 1111  {"id":337,"name":"Gadgets","slug":"technology/...      US
# 1152  {"id":337,"name":"Gadgets","slug":"technology/...      US
# 1190  {"id":337,"name":"Gadgets","slug":"technology/...      US
# 1612  {"id":46,"name":"Children's Books","slug":"pub...      US
# 1777  {"id":46,"name":"Children's Books","slug":"pub...      US
# 2475  {"id":21,"name":"Digital Art","slug":"art/digi...      US
# 2535  {"id":23,"name":"Painting","slug":"art/paintin...      US
# 2561  {"id":23,"name":"Painting","slug":"art/paintin...      US
# 2725  {"id":21,"name":"Digital Art","slug":"art/digi...      US
# 2748  {"id":23,"name":"Painting","slug":"art/paintin...      US
# 2994  {"id":23,"name":"Painting","slug":"art/paintin...      US
# 3251  {"id":252,"name":"Graphic Novels","slug":"comi...      US
#
#      country_displayable_name          created_at            deadline  \
# 203                     Spain 2021-01-10 08:44:34 2021-03-18 14:27:57
# 363                     Spain 2021-01-10 08:44:34 2021-03-18 14:27:57
# 402         the United States 2019-10-18 15:38:16 2019-12-04 02:56:54
# 586                 Hong Kong 2019-07-29 11:51:39 2019-10-04 13:30:03
# 604                 Australia 2019-12-07 22:55:31 2020-04-29 22:01:09
# 675                 Australia 2019-12-07 22:55:31 2020-04-29 22:01:09
# 937         the United States 2019-02-11 15:56:10 2019-07-02 03:54:32
# 988                 Hong Kong 2019-07-29 11:51:39 2019-10-04 13:30:03
# 1111        the United States 2020-07-05 20:21:40 2020-08-19 19:56:52
# 1152        the United States 2019-02-11 15:56:10 2019-07-02 03:54:32
# 1190        the United States 2020-07-05 20:21:40 2020-08-19 19:56:52
# 1612        the United States 2020-12-06 17:01:36 2021-02-18 15:55:15
# 1777        the United States 2020-12-06 17:01:36 2021-02-18 15:55:15
# 2475        the United States 2021-02-28 09:56:18 2021-03-29 04:59:00
# 2535        the United States 2020-10-22 18:03:45 2020-12-15 19:55:39
# 2561        the United States 2012-08-09 22:45:05 2012-09-28 15:59:00
# 2725        the United States 2021-02-28 09:56:18 2021-03-29 04:59:00
# 2748        the United States 2020-10-22 18:03:45 2020-12-15 19:55:39
# 2994        the United States 2012-08-10 02:32:19 2012-09-29 03:59:00
# 3251        the United States 2019-10-18 15:38:16 2019-12-04 02:56:54
#
#       disable_communication      goal          id  is_starrable  \
# 203                   False   14100.0   528274403         False
# 363                   False   14100.0   528274403         False
# 402                   False     500.0  1880551383         False
# 586                   False  150000.0  1282938902         False
# 604                   False   10800.0   905929551         False
# 675                   False   10800.0   905929551         False
# 937                   False   60000.0   372360890         False
# 988                   False  150000.0  1282938902         False
# 1111                  False     300.0   881319076         False
# 1152                  False   60000.0   372360890         False
# 1190                  False     300.0   881319076         False
# 1612                  False     500.0   825031170         False
# 1777                  False     500.0   825031170         False
# 2475                  False     300.0  1829720595          True
# 2535                  False   18000.0   522881743         False
# 2561                  False    3500.0   175864201         False
# 2725                  False     300.0  1829720595          True
# 2748                  False   18000.0   522881743         False
# 2994                  False    3500.0   262646351         False
# 3251                  False     500.0  1880551383         False
#
#              launched_at                                           location  \
# 203  2021-02-11 15:27:57  {"id":753692,"name":"Barcelona","slug":"barcel...
# 363  2021-02-11 15:27:57  {"id":753692,"name":"Barcelona","slug":"barcel...
# 402  2019-11-04 02:56:54  {"id":2490383,"name":"Seattle","slug":"seattle...
# 586  2019-08-15 13:30:03  {"id":2390774,"name":"Delaware","slug":"delawa...
# 604  2020-02-29 23:01:09  {"id":1104584,"name":"Newcastle","slug":"newca...
# 675  2020-02-29 23:01:09  {"id":1104584,"name":"Newcastle","slug":"newca...
# 937  2019-05-23 03:54:32  {"id":2508533,"name":"Tulsa","slug":"tulsa-ok"...
# 988  2019-08-15 13:30:03  {"id":2390774,"name":"Delaware","slug":"delawa...
# 1111 2020-07-20 19:56:52  {"id":2433074,"name":"Kirkland","slug":"kirkla...
# 1152 2019-05-23 03:54:32  {"id":2508533,"name":"Tulsa","slug":"tulsa-ok"...
# 1190 2020-07-20 19:56:52  {"id":2433074,"name":"Kirkland","slug":"kirkla...
# 1612 2021-01-12 15:55:15  {"id":2487956,"name":"San Francisco","slug":"s...
# 1777 2021-01-12 15:55:15  {"id":2487956,"name":"San Francisco","slug":"s...
# 2475 2021-03-08 06:25:05  {"id":2424766,"name":"Houston","slug":"houston...
# 2535 2020-11-10 19:55:39  {"id":12589342,"name":"Manhattan","slug":"manh...
# 2561 2012-08-29 16:31:19  {"id":2358820,"name":"Baltimore","slug":"balti...
# 2725 2021-03-08 06:25:05  {"id":2424766,"name":"Houston","slug":"houston...
# 2748 2020-11-10 19:55:39  {"id":12589342,"name":"Manhattan","slug":"manh...
# 2994 2012-08-24 19:37:48  {"id":2381475,"name":"Cleveland","slug":"cleve...
# 3251 2019-11-04 02:56:54  {"id":2490383,"name":"Seattle","slug":"seattle...
#
#                                                    name  staff_pick  \
# 203                       Self Unlimited Create Mandala       False
# 363                       Self Unlimited Create Mandala       False
# 402      The Book of Jessica Issue 4 AND Graphic Novel.       False
# 586   Wisenfit: New Generation Phone-Powered Electri...       False
# 604                                        Recovery Box       False
# 675                                        Recovery Box       False
# 937          The GRILLGUN..."The Ultimate Grill Torch!"       False
# 988   Wisenfit: New Generation Phone-Powered Electri...       False
# 1111  B.E.A.R. Privacy: Touch-less Protection for Sm...       False
# 1152         The GRILLGUN..."The Ultimate Grill Torch!"       False
# 1190  B.E.A.R. Privacy: Touch-less Protection for Sm...       False
# 1612  Make 100 : UMA – A Children’s Book About Hindu...        True
# 1777  Make 100 : UMA – A Children’s Book About Hindu...        True
# 2475                Lunar New Year Zodiacs: Enamel Pins       False
# 2535  Help us make a permanent home for The Black Pa...        True
# 2561               Artists 2 Africa- Larry Poncho Brown       False
# 2725                Lunar New Year Zodiacs: Enamel Pins       False
# 2748  Help us make a permanent home for The Black Pa...        True
# 2994                  Artists 2 Africa- Jerome T. White       False
# 3251     The Book of Jessica Issue 4 AND Graphic Novel.       False
#
#            state  static_usd_rate    usd_pledged
# 203         live         1.212886     918.154475
# 363         live         1.212886     918.154475
# 402   successful         1.000000     983.000000
# 586   successful         0.127454   43191.709795
# 604   successful         0.652425    7176.884876
# 675   successful         0.652425    7176.884876
# 937   successful         1.000000  405913.000000
# 988   successful         0.127454   43191.709795
# 1111  successful         1.000000     516.000000
# 1152  successful         1.000000  405913.000000
# 1190  successful         1.000000     516.000000
# 1612  successful         1.000000    1471.000000
# 1777  successful         1.000000    1471.000000
# 2475        live         1.000000     445.000000
# 2535  successful         1.000000   22240.000000
# 2561  successful         1.000000    4607.000000
# 2725        live         1.000000     445.000000
# 2748  successful         1.000000   22240.000000
# 2994  successful         1.000000    3650.000000
# 3251  successful         1.000000     983.000000

# %%
#see 'id' for rows where blurbs are duplicates
df[blurbs.isin(blurbs[blurbs.duplicated()])]['id']
# Out:
# 203      528274403
# 363      528274403
# 402     1880551383
# 586     1282938902
# 604      905929551
# 675      905929551
# 937      372360890
# 988     1282938902
# 1111     881319076
# 1152     372360890
# 1190     881319076
# 1612     825031170
# 1777     825031170
# 2475    1829720595
# 2535     522881743
# 2561     175864201
# 2725    1829720595
# 2748     522881743
# 2994     262646351
# 3251    1880551383
# Name: id, dtype: int64

# %% [markdown]
# explore ids #175864201 and #262646351 where blurbs are identical but ids are not identical;
# per below, choosing to keep observations for ids #175864201 and #262646351

# %%
df.iloc[2561] == df.iloc[2994]
# Out:
# backers_count               False
# blurb                       False
# category                    False
# converted_pledged_amount    False
# country                     False
# country_displayable_name    False
# created_at                  False
# creator                     False
# currency                    False
# currency_symbol             False
# currency_trailing_code      False
# current_currency             True
# deadline                    False
# disable_communication        True
# friends                     False
# fx_rate                     False
# goal                        False
# id                          False
# is_backing                  False
# is_starrable                 True
# is_starred                  False
# launched_at                 False
# location                    False
# name                        False
# permissions                 False
# photo                       False
# pledged                     False
# profile                     False
# slug                        False
# source_url                  False
# spotlight                   False
# staff_pick                   True
# state                       False
# state_changed_at            False
# static_usd_rate             False
# urls                        False
# usd_pledged                 False
# usd_type                     True
# dtype: bool

# %% [markdown]
# ### extracting categories and subcategories

# %%
# Example category value
df.iloc[0]['category']
# Out:
# '{"id":345,"name":"DIY","slug":"crafts/diy","position":3,"parent_id":26,"parent_name":"Crafts","color":16744876,"urls":{"web":{"discover":"http://www.kickstarter.com/discover/categories/crafts/diy"}}}'

# %%
# Extracting the relevant sub-category section from the string
f = lambda x: x['category'].split('/')[1].split('","position')[0]
df['sub_category'] = df.apply(f, axis=1)

# Extracting the relevant category section from the string, and replacing the original category variable
f = lambda x: x['category'].split('"slug":"')[1].split('/')[0]
df['category'] = df.apply(f, axis=1)
f = lambda x: x['category'].split('","position"')[0] # Some categories do not have a sub-category, so do not have a '/' to split with
df['category'] = df.apply(f, axis=1)
